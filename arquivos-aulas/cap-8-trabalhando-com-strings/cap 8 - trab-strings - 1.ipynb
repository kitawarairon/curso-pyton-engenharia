# %% [markdown]
# # Variáveis strings
#
# *  Strings;
# *  print e input;

# %% [markdown]
# ## Strings
#
# As strings são:
#
# > **Imutáveis**
#
# > **Iteráveis**
#
# >**Acessível pelo índice**

# %%
nome = 'Alexandre, o Grande'

# %%
nome[3]
# Out:
# 'x'

# %%
nome[-6]
# Out:
# 'G'

# %%
nome[-6:]
# Out:
# 'Grande'

# %%
nome[-6:-1]
# Out:
# 'Grand'

# %% [markdown]
# ## print e input
#
# * **<font color="purple">print()</font>**
#
# A grosso modo a função print() serve para imprimir os argumentos passados a ela no terminal.
#
# ![image.png](attachment:image.png)

# %%
print(1, 1.0, 'string', True)
# Out:
# 1 1.0 string True

# %%
print('O rato', 4, 'Roma', sep=' ')
# Out:
# O rato 4 Roma

# %%
print('O rato', 4, 'Roma', sep='<->')
# Out:
# O rato<->4<->Roma

# %%
print('O rato', 4, 'Roma', sep='')
# Out:
# O rato4Roma

# %%
print('O rato', 4, 'Roma', end='\n')
print('Teste 12345789')
# Out:
# O rato 4 Roma
# Teste 12345789

# %%
print('O rato', 4, 'Roma', end=' ')
print('Teste 12345789')
# Out:
# O rato 4 Roma Teste 12345789

# %% [markdown]
# * **<font color="purple">input()</font>**
#
# A função `input()` faz uma pausa no programa e espera uma entrada do usuário pelo terminal. Para ler a entrada do usuário a função input() espera que após digitada a entrada o usuário aperte a tecla enter, após isso `input()` lê essa entrada como uma _string_, portanto, se a entrada esperada for um número ela deve ser convertida usando-se as funções de conversão `int()` ou `float()`.

# %%
input(prompt='Digite alguma coisa')
# Out:
# Digite alguma coisaadasd
# 'adasd'
