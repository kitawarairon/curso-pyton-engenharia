# %% [markdown]
# # Preparando ambiente
# ---
# * Organizando o ambiente!
# * Instalando o ananconda!
# * Instalando o Pycharm !

# %% [markdown]
# ## Organizando o ambiente
# ---
# * Crie um pasta e baixe o repositório com todos os arquivos do curso!
# * [Repositório](https://github.com/kitawarairon/curso-pyton-engenharia)

# %% [markdown]
# ## Instalando o anaconda!
#
# ![image.png](attachment:image.png)
#
# * Baixe o arquivo do [anaconda](https://www.anaconda.com/products/individual)
# * Instale o anaconda!

# %% [markdown]
# ## Instalando o Pycharm!
#
# ![image.png](attachment:image.png)
#
# * Baixe o arquivo do [pycharm](https://www.jetbrains.com/pt-br/pycharm/download/#section=windows)
# * Instale o anaconda!
